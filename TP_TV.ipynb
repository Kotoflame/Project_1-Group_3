# %%
#import functions

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import csv TV 

tv_df = pd.read_csv("Resources/Cleaned_TV_2013.csv")
tv_df
# Out:
#      Year Month        Date  Value  3-Month % Change
# 0    2013   M01  2013-01-01   52.0              -3.0
# 1    2013   M02  2013-02-01   51.9              -0.6
# 2    2013   M03  2013-03-01   51.1              -2.1
# 3    2013   M04  2013-04-01   51.0              -1.9
# 4    2013   M05  2013-05-01   50.9              -1.9
# ..    ...   ...         ...    ...               ...
# 118  2022   M11  2022-11-01   41.4               2.7
# 119  2022   M12  2022-12-01   41.4               3.2
# 120  2023   M01  2023-01-01   41.4              -0.7
# 121  2023   M02  2023-02-01   41.4               0.0
# 122  2023   M03  2023-03-01   41.1              -0.7
#
# [123 rows x 5 columns]

# %%
#Get average value per year
yearly_avg = tv_df.groupby('Year')['Value'].mean()

# %%
# Dataframe for TV Value

# Convert 'Date' column to datetime format
tv_df['Date'] = pd.to_datetime(tv_df['Date'])

# Set 'Date' column as the index
tv_df = tv_df.set_index('Date')

# Create a figure and axis objects
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the '3-Month % Change' column as a line plot
ax.plot(tv_df['Value'], linewidth=1.5, color='blue')


# Add labels and a title
ax.set_xlabel('Date')
ax.set_ylabel('3-Month % Change')
ax.set_title('TV Value Change over Time')

# Display the graph
plt.show()

# %%
# Dataframe for TV 3 Month % change

# Convert 'Date' column to datetime format
tv_df['Date'] = pd.to_datetime(tv_df['Date'])

# Set 'Date' column as the index
tv_df = tv_df.set_index('Date')

# Create a figure and axis objects
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the '3-Month % Change' column as a line plot
ax.plot(tv_df['3-Month % Change'], linewidth=1.5, color='blue')


# Add labels and a title
ax.set_xlabel('Date')
ax.set_ylabel('3-Month % Change')
ax.set_title('TV 3-Month Change over Time')

# Display the graph
plt.show()

# %%
# import csv TP

tp_df = pd.read_csv("Resources/Cleaned_TP_2013.csv")
tp_df
# Out:
#      Year Month        Date    Value  3-Month % Change
# 0    2013   M01  2013-01-01  132.300               0.0
# 1    2013   M02  2013-02-01  132.300               0.0
# 2    2013   M03  2013-03-01  131.900              -0.3
# 3    2013   M04  2013-04-01  131.900              -0.3
# 4    2013   M05  2013-05-01  131.800              -0.4
# ..    ...   ...         ...      ...               ...
# 119  2022   M12  2022-12-01  167.031               3.5
# 120  2023   M01  2023-01-01  168.545               3.8
# 121  2023   M02  2023-02-01  170.254               2.4
# 122  2023   M03  2023-03-01  169.497               1.5
# 123  2023   M04  2023-04-01  169.178               0.4
#
# [124 rows x 5 columns]

# %%
#Get average value per year
yearly_avg = tp_df.groupby('Year')['Value'].mean()

# %%
# DataFrame for Toilet Paper Value

# Convert 'Date' column to datetime format
tp_df['Date'] = pd.to_datetime(tp_df['Date'])

# Set 'Date' column as the index
tp_df = tp_df.set_index('Date')

# Create a figure and axis objects
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the '3-Month % Change' column as a line plot
ax.plot(tp_df['Value'], linewidth=1.5, color='blue')

# Set the y-axis limits and ticks
#ax.set_ylim(-6, 6)
#ax.set_yticks(range(-6, 7, 2))

# Add labels and a title
ax.set_xlabel('Date')
ax.set_ylabel('3-Month % Change')
ax.set_title('Toliet Paper Value Change over Time')

# Display the graph
plt.show()

# %%
# DataFrame for Toilet Paper 3-Month % change

# Convert 'Date' column to datetime format
tp_df['Date'] = pd.to_datetime(tp_df['Date'])

# Set 'Date' column as the index
tp_df = tp_df.set_index('Date')

# Create a figure and axis objects
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the '3-Month % Change' column as a line plot
ax.plot(tp_df['Value'], linewidth=1.5, color='blue')

# Set the y-axis limits and ticks
#ax.set_ylim(-6, 6)
#ax.set_yticks(range(-6, 7, 2))

# Add labels and a title
ax.set_xlabel('Date')
ax.set_ylabel('3-Month % Change')
ax.set_title('Toilet Paper 3-Month % Change over Time')

# Display the graph
plt.show()

# %%
# plot both TV and TP Value 

fig, ax = plt.subplots(figsize=(10, 5))

# plot TV data as red line
ax.plot(tv_df['Year'], tv_df['Value'], color='red', label='TV')

# plot TP data as blue line
ax.plot(tp_df['Year'], tp_df['Value'], color='blue', label='TP')

# add title and axis labels
ax.set_title('TV and Toilet Paper Value Change by Year')
ax.set_xlabel('Year')
ax.set_ylabel('3-Month % Change')

# add legend
ax.legend()

# display the plot
plt.show()

# %%
# plot both TV and TP 3 month % change

fig, ax = plt.subplots(figsize=(15, 10))

# plot TV data as red line
ax.plot(tv_df['Year'], tv_df['3-Month % Change'], color='red', label='TV')

# plot TP data as blue line
ax.plot(tp_df['Year'], tp_df['3-Month % Change'], color='blue', label='TP')

# add title and axis labels
ax.set_title('TV and Toilet Paper 3-Month % Change')
ax.set_xlabel('Year')
ax.set_ylabel('3-Month % Change')

# add legend
ax.legend()

# display the plot
plt.show()
